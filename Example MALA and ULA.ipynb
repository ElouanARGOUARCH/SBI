# %%
from targets.variational_inference_target import *
import matplotlib.pyplot as plt
target = Dimension1()

# %%
from samplers import MALA

# %%
mala = MALA(target.log_prob,1,1000)
x = mala.sample(1000)
hist = plt.hist(x.detach().numpy(), bins = 200, density = True)
tt = torch.linspace(-12,12,100)
plt.plot(tt, torch.exp(target.log_prob(tt.unsqueeze(-1))).numpy(), color = 'red')
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 175.65it/s, acceptance = tensor(0.9890)]

# %%
from samplers import ULA

# %%
ula = ULA(target.log_prob,1,10000)
x = ula.sample(1000)
hist = plt.hist(x.detach().numpy(), bins = 200, density = True)
tt = torch.linspace(-12,12,100)
plt.plot(tt, torch.exp(target.log_prob(tt.unsqueeze(-1))).numpy(), color = 'red')
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 534.13it/s]
