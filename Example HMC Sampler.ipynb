# %%
from targets.variational_inference_target import *
target = Orbits()
from samplers import HMC
import matplotlib.pyplot as plt

# %%
sampler = HMC(target.log_prob,2, number_chains = 500)
x = sampler.sample(100)
plt.scatter(x[:,0].detach().numpy(),x[:,1].detach().numpy())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 69.26it/s, acceptance = tensor(1.)]

# %%
for i in range(10):
    trajectory=sampler.sample_trajectory(500)
    plt.plot(trajectory[:,0].detach().numpy(),trajectory[:,1].detach().numpy())
plt.show()
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:03<00:00, 137.91it/s, acceptance = tensor(0.)]
